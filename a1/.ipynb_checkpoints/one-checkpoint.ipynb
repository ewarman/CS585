# %%
#Read in all data
names = list(range(1,199))
labeled_sentences = []
sentence=[]
for name in names:
    file = open('dependency_treebank/wsj_'+str(name).zfill(4)+'.dp', 'r')
    for line in file.readlines():
        tokens = line.split("\t")
        word = ()
        if (len(tokens)>1):
            word = (tokens[0],tokens[1])
            sentence.append(word)
            if(tokens[1] == '.'):
                labeled_sentences.append(sentence)
                sentence = []

# %%
#Assign the first 90% of sentences to the training set and the remaining 10% to the test set
import math

split = math.ceil(len(labeled_sentences)*.9)
print('Split at %d' % split)
training_set = labeled_sentences[:split]
test_set = labeled_sentences[split:]
# Out:
# Split at 3484

# %%
#Create an unlabeled copy of the test set to tag
unlabeled_test_set = []
sentence = []
for item in test_set:
    for word in item:
        sentence.append(word[0])
    unlabeled_test_set.append(sentence)
    sentence = []

# %%
def evaluate_average(model):
    """Computes the average accuracy of a model. Evaluates accuracy sentence by sentence and
    takes the average to give long sentences the same weight as short sentences"""
    total = 0
    wrapper = []
    for sentence in test_set:
        wrapper.append(sentence)
        val = model.evaluate(wrapper)
        wrapper = []
        total += val
    avg = total/len(test_set)
    print('Average Accuracy:',avg)
    return avg

# %%
from nltk.util import unique_list
import numpy as np
import pandas as pd
import matplotlib as mpl
from matplotlib import pyplot

def create_table(name,results,tag_set):
    """Writes the results matrix for each model to a .csv file"""
    table = pd.DataFrame(results, index=tag_set, columns=tag_set)
    filename = name+'.csv'
    table.to_csv(filename, sep='\t')

def create_visualization(confusion_matrix):
    """Creates a beautiful confusion matrix visualization"""
    cmap = mpl.colors.ListedColormap(['white','yellow','orange','red'])
    bounds=[0,2,7,25,1420]
    norm = mpl.colors.BoundaryNorm(bounds,cmap.N)

    img = pyplot.imshow(confusion_matrix,interpolation='nearest',cmap=cmap,norm=norm)
    pyplot.colorbar(img,cmap=cmap,norm=norm,boundaries=bounds,ticks=bounds)
    pyplot.show()

def precision_recall(model,name):
    """Calculates the average precision and recall scores for each model by creating 
    a confusion matrix with the dimensions of the tagset. For each part of speech:
    precision = (# of correct tags)/(total tagged in testing)
    recall = (# of correct tags)/(total tagged in hand labeled set)
    The precision and recall values are summed over all of the parts of speech and
    divided by the number of parts of speech observed."""
    tag_set = unique_list(tag for sent in test_set+training_set
            for word, tag in sent)
    tag_set.append(None)
    indices = list(range(0,len(tag_set)))
    lookup = dict(zip(tag_set, indices))
    confusion_matrix = np.zeros((len(indices),len(indices)))
    for idx,sentence in enumerate(unlabeled_test_set):
        predicted = model.tag(sentence)
        print(predicted)
        for prediction,labeled in zip(predicted,test_set[idx]):
            confusion_matrix[lookup[prediction[1]]][lookup[labeled[1]]] += 1
    
    #create_table(name,confusion_matrix,tag_set)
    #create_visualization(confusion_matrix)
    
    precision=[]
    recall=[]
    tag_predictions = confusion_matrix.sum(axis=0)
    tag_occurences = confusion_matrix.sum(axis=1)
    for idx in indices[:-1]:
        num_correct = confusion_matrix[idx][idx]
        total_predicted = tag_predictions[idx]
        total_occurrences = tag_occurences[idx]
        if (total_predicted!=0):
            precision.append(num_correct/tag_predictions[idx])
        if (total_occurrences!=0):
            recall.append(num_correct/tag_occurences[idx]) 
    avg_precision = sum(precision)/len(precision)
    avg_recall = sum(recall)/len(recall)
    print('Average Precision:',avg_precision)
    print('Average Recall:',avg_recall)
    results = (avg_precision, avg_recall)
    return results

# %%
def compute_accuracy(model,name):
    """Computes overall accuracy, average accuracy, precision, and recall for the desired
    model"""
    pct = model.evaluate(test_set)
    print('Overall Accuracy:',pct)

    avg = evaluate_average(model)
    pr = precision_recall(model,name)
    results = [pct, avg, pr[0], pr[1]]
    return results

# %%
#accuracy computations for each model
import nltk
from collections import OrderedDict

results = OrderedDict()

unigram_tagger = nltk.UnigramTagger(training_set)
results['Unigram'] = compute_accuracy(unigram_tagger,'unigram')
# Out:
# Overall Accuracy: 0.8542409508373852
# Average Accuracy: 0.8529120249815192
# 1220.0
# Average Precision: 0.813363992136
# Average Recall: 0.917322175822

# %%
bigram_tagger = nltk.BigramTagger(training_set)
results['Bigram'] = compute_accuracy(bigram_tagger,'bigram')
# Out:
# Overall Accuracy: 0.13452188006482982
# Average Accuracy: 0.16265216972954502
# [('New', 'NNP'), ('loans', None), ('continue', None), ('to', None), ('slow', None), (';', None), ('they', None), ('were', None), ('$', None), ('6.6', None), ('million', None), ('in', None), ('the', None), ('quarter', None), ('compared', None), ('with', None), ('$', None), ('361.8', None), ('million', None), ('a', None), ('year', None), ('ago', None), ('.', None)]
# [('The', 'DT'), ('thrift', 'NN'), ('has', 'VBZ'), ('assets', None), ('of', None), ('$', None), ('3.2', None), ('billion', None), ('.', None)]
# [('First', 'NNP'), ('of', 'IN'), ('America', 'NNP'), ('Bank', 'NNP'), ('Corp.', 'NNP'), ('said', 'VBD'), ('it', 'PRP'), ('completed', 'VBD'), ('its', 'PRP$'), ('acquisition', 'NN'), ('of', 'IN'), ('Midwest', None), ('Financial', None), ('Group', None), ('Inc.', None), ('for', None), ('about', None), ('$', None), ('250', None), ('million', None), ('.', None)]
# [('First', 'NNP'), ('of', 'IN'), ('America', 'NNP'), (',', ','), ('which', 'WDT'), ('now', 'RB'), ('has', 'VBZ'), ('45', None), ('banks', None), ('and', None), ('$', None), ('12.5', None), ('billion', None), ('in', None), ('assets', None), (',', None), ('announced', None), ('an', None), ('agreement', None), ('to', None), ('acquire', None), ('the', None), ('Peoria', None), (',', None), ('Ill.', None), (',', None), ('bank', None), ('holding', None), ('company', None), ('in', None), ('January', None), ('.', None)]
# [('Midwest', None), ('Financial', None), ('has', None), ('$', None), ('2.3', None), ('billion', None), ('in', None), ('assets', None), ('and', None), ('eight', None), ('banks', None), ('.', None)]
# [('The', 'DT'), ('Midwest', 'NN'), ('Financial', None), ('subsidiary', None), ('banks', None), ('will', None), ('continue', None), ('to', None), ('operate', None), ('under', None), ('their', None), ('current', None), ('names', None), ('until', None), ('early', None), ('1990', None), (',', None), ('when', None), ('each', None), ('will', None), ('adopt', None), ('the', None), ('First', None), ('of', None), ('America', None), ('name', None), ('.', None)]
# [('Kalamazoo', None), (',', None), ('Mich.-based', None), ('First', None), ('of', None), ('America', None), ('said', None), ('it', None), ('will', None), ('eliminate', None), ('the', None), ('13', None), ('management', None), ('positions', None), ('of', None), ('the', None), ('former', None), ('Midwest', None), ('Financial', None), ('parent', None), ('company', None), ('.', None)]
# [('First', 'NNP'), ('of', 'IN'), ('America', 'NNP'), ('said', 'VBD'), ('some', 'DT'), ('of', 'IN'), ('the', 'DT'), ('managers', 'NNS'), ('will', 'MD'), ('take', 'VB'), ('other', 'JJ'), ('jobs', 'NNS'), ('with', 'IN'), ('First', 'NNP'), ('of', 'IN'), ('America', 'NNP'), ('.', '.')]
# [('But', 'CC'), ('it', 'PRP'), ('said', 'VBD'), ('that', 'IN'), ('severance', None), ('payments', None), ('to', None), ('those', None), ('executives', None), ('not', None), ('staying', None), ('with', None), ('the', None), ('company', None), ('will', None), ('reduce', None), ('First', None), ('of', None), ('America', None), ("'s", None), ('operating', None), ('results', None), ('for', None), ('1989', None), ('by', None), ('$', None), ('3', None), ('million', None), ('to', None), ('$', None), ('4', None), ('million', None), (',', None), ('or', None), ('15', None), ('cents', None), ('to', None), ('20', None), ('cents', None), ('a', None), ('share', None), ('.', None)]
# [('Coleco', None), ('Industries', None), ('Inc.', None), (',', None), ('a', None), ('once', None), ('high-flying', None), ('toy', None), ('maker', None), ('whose', None), ('stock', None), ('peaked', None), ('at', None), ('$', None), ('65', None), ('a', None), ('share', None), ('in', None), ('the', None), ('early', None), ('1980s', None), (',', None), ('filed', None), ('a', None), ('Chapter', None), ('11', None), ('reorganization', None), ('plan', None), ('that', None), ('provides', None), ('just', None), ('1.125', None), ('cents', None), ('a', None), ('share', None), ('for', None), ('common', None), ('stockholders', None), ('.', None)]
# [('Under', 'IN'), ('the', 'DT'), ('plan', 'NN'), (',', ','), ('unsecured', None), ('creditors', None), (',', None), ('who', None), ('are', None), ('owed', None), ('about', None), ('$', None), ('430', None), ('million', None), (',', None), ('would', None), ('receive', None), ('about', None), ('$', None), ('92', None), ('million', None), (',', None), ('or', None), ('21', None), ('cents', None), ('for', None), ('each', None), ('dollar', None), ('they', None), ('are', None), ('owed', None), ('.', None)]
# [('In', 'IN'), ('addition', 'NN'), (',', ','), ('they', 'PRP'), ('will', 'MD'), ('receive', 'VB'), ('stock', 'NN'), ('in', 'IN'), ('the', 'DT'), ('reorganized', None), ('company', None), (',', None), ('which', None), ('will', None), ('be', None), ('named', None), ('Ranger', None), ('Industries', None), ('Inc', None), ('.', None)]
# [('After', 'IN'), ('these', 'DT'), ('payments', 'NNS'), (',', ','), ('about', 'IN'), ('$', '$'), ('225,000', None), ('will', None), ('be', None), ('available', None), ('for', None), ('the', None), ('20', None), ('million', None), ('common', None), ('shares', None), ('outstanding', None), ('.', None)]
# [('The', 'DT'), ('Avon', None), (',', None), ('Conn.', None), (',', None), ('company', None), ("'s", None), ('stock', None), ('hit', None), ('a', None), ('high', None), ('in', None), ('1983', None), ('after', None), ('it', None), ('unveiled', None), ('its', None), ('Adam', None), ('home', None), ('computer', None), (',', None), ('but', None), ('the', None), ('product', None), ('was', None), ('plagued', None), ('with', None), ('glitches', None), ('and', None), ('the', None), ('company', None), ("'s", None), ('fortunes', None), ('plunged', None), ('.', None)]
# [('But', 'CC'), ('Coleco', None), ('bounced', None), ('back', None), ('with', None), ('the', None), ('introduction', None), ('of', None), ('the', None), ('Cabbage', None), ('Patch', None), ('dolls', None), (',', None), ('whose', None), ('sales', None), ('hit', None), ('$', None), ('600', None), ('million', None), ('in', None), ('1985', None), ('.', None)]
# [('But', 'CC'), ('as', 'IN'), ('the', 'DT'), ('craze', None), ('died', None), (',', None), ('Coleco', None), ('failed', None), ('to', None), ('come', None), ('up', None), ('with', None), ('another', None), ('winner', None), ('and', None), ('filed', None), ('for', None), ('bankruptcy-law', None), ('protection', None), ('in', None), ('July', None), ('1988', None), ('.', None)]
# [('The', 'DT'), ('plan', 'NN'), ('was', 'VBD'), ('filed', 'VBN'), ('jointly', 'RB'), ('with', 'IN'), ('unsecured', None), ('creditors', None), ('in', None), ('federal', None), ('bankruptcy', None), ('court', None), ('in', None), ('New', None), ('York', None), ('and', None), ('must', None), ('be', None), ('approved', None), ('by', None), ('the', None), ('court', None), ('.', None)]
# [('ORTEGA', None), ('ENDED', None), ('a', None), ('truce', None), ('with', None), ('the', None), ('Contras', None), ('and', None), ('said', None), ('elections', None), ('were', None), ('threatened', None), ('.', None)]
# [('The', 'DT'), ('Nicaraguan', None), ('president', None), (',', None), ('citing', None), ('attacks', None), ('by', None), ('the', None), ('U.S.-backed', None), ('rebels', None), (',', None), ('suspended', None), ('a', None), ('19-month-old', None), ('cease-fire', None), ('and', None), ('accused', None), ('Bush', None), ('of', None), ('``', None), ('promoting', None), ('death', None), ('.', None)]
# [("''", "''"), ('While', 'IN'), ('he', 'PRP'), ('reaffirmed', None), ('support', None), ('for', None), ('the', None), ('country', None), ("'s", None), ('Feb.', None), ('25', None), ('elections', None), (',', None), ('Ortega', None), ('indicated', None), ('that', None), ('renewed', None), ('U.S.', None), ('military', None), ('aid', None), ('to', None), ('the', None), ('Contras', None), ('could', None), ('thwart', None), ('the', None), ('balloting', None), ('.', None)]
# [('He', 'PRP'), ('said', 'VBD'), ('U.S.', 'NNP'), ('assistance', None), ('should', None), ('be', None), ('used', None), ('to', None), ('demobilize', None), ('the', None), ('rebels', None), ('.', None)]
# [('A', 'DT'), ('White', 'NNP'), ('House', 'NNP'), ('spokesman', 'NN'), ('condemned', None), ('the', None), ('truce', None), ('suspension', None), ('as', None), ('``', None), ('deplorable', None), ("''", None), ('but', None), ('brushed', None), ('off', None), ('talk', None), ('of', None), ('renewing', None), ('military', None), ('funding', None), ('for', None), ('the', None), ('insurgents', None), ('.', None)]
# [('The', 'DT'), ('Contra', None), ('military', None), ('command', None), (',', None), ('in', None), ('a', None), ('statement', None), ('from', None), ('Honduras', None), (',', None), ('said', None), ('Sandinista', None), ('troops', None), ('had', None), ('launched', None), ('a', None), ('major', None), ('offensive', None), ('against', None), ('the', None), ('rebel', None), ('forces', None), ('.', None)]
# [('East', None), ('German', None), ('leader', None), ('Krenz', None), ('called', None), ('the', None), ('protests', None), ('in', None), ('his', None), ('country', None), ('a', None), ('``', None), ('good', None), ('sign', None), (',', None), ("''", None), ('saying', None), ('that', None), ('many', None), ('of', None), ('those', None), ('marching', None), ('for', None), ('democratic', None), ('freedoms', None), ('were', None), ('showing', None), ('support', None), ('for', None), ('``', None), ('the', None), ('renovation', None), ('for', None), ('socialism', None), ('.', None)]
# [("''", "''"), ('The', 'DT'), ('Communist', None), ('Party', None), ('chief', None), (',', None), ('in', None), ('Moscow', None), ('for', None), ('talks', None), ('with', None), ('Soviet', None), ('officials', None), (',', None), ('also', None), ('said', None), ('East', None), ('Germany', None), ('would', None), ('follow', None), ('Gorbachev', None), ("'s", None), ('restructuring', None), ('plans', None), ('.', None)]
# [('Thousands', None), ('of', None), ('East', None), ('Germans', None), ('fled', None), ('to', None), ('Czechoslovakia', None), ('after', None), ('the', None), ('East', None), ('Berlin', None), ('government', None), ('lifted', None), ('travel', None), ('restrictions', None), ('.', None)]
# [('The', 'DT'), ('ban', 'NN'), ('on', 'IN'), ('cross-border', None), ('movement', None), ('was', None), ('imposed', None), ('last', None), ('month', None), ('after', None), ('a', None), ('massive', None), ('exodus', None), ('of', None), ('emigres', None), ('to', None), ('West', None), ('Germany', None), ('.', None)]
# [('Also', 'RB'), (',', ','), ('a', 'DT'), ('Communist', None), ('official', None), ('for', None), ('the', None), ('first', None), ('time', None), ('said', None), ('the', None), ('future', None), ('of', None), ('the', None), ('Berlin', None), ('Wall', None), ('could', None), ('be', None), ('open', None), ('to', None), ('discussion', None), ('.', None)]
# [('Health', None), ('officials', None), ('plan', None), ('to', None), ('extend', None), ('a', None), ('moratorium', None), ('on', None), ('federal', None), ('funding', None), ('of', None), ('research', None), ('involving', None), ('fetal-tissue', None), ('transplants', None), ('.', None)]
# [('The', 'DT'), ('assistant', 'JJ'), ('HHS', None), ('secretary', None), ('said', None), ('the', None), ('ban', None), ('``', None), ('should', None), ('be', None), ('continued', None), ('indefinitely', None), ('.', None)]
# [("''", "''"), ('While', 'IN'), ('researchers', 'NNS'), ('believe', 'VBP'), ('such', 'JJ'), ('transplants', 'NNS'), ('could', 'MD'), ('help', 'VB'), ('treat', 'VB'), ('diseases', None), ('like', None), ('Alzheimer', None), ("'s", None), (',', None), ('anti-abortionists', None), ('oppose', None), ('the', None), ('research', None), ('.', None)]
# [('Rep.', 'NNP'), ('Dingell', 'NNP'), ('of', 'IN'), ('Michigan', None), ('plans', None), ('to', None), ('unveil', None), ('today', None), ('a', None), ('proposal', None), ('that', None), ('would', None), ('break', None), ('with', None), ('Bush', None), ("'s", None), ('clean-air', None), ('bill', None), ('on', None), ('the', None), ('issue', None), ('of', None), ('emissions', None), ('that', None), ('lead', None), ('to', None), ('acid', None), ('rain', None), ('.', None)]
# [('The', 'DT'), ('Democrat', None), ("'s", None), ('proposal', None), ('is', None), ('described', None), ('by', None), ('government', None), ('sources', None), ('and', None), ('lobbyists', None), ('as', None), ('significantly', None), ('weaker', None), ('than', None), ('the', None), ('president', None), ("'s", None), ('plan', None), ('to', None), ('cut', None), ('utility', None), ('emissions', None), ('.', None)]
# [('House-Senate', None), ('conferees', None), ('approved', None), ('major', None), ('portions', None), ('of', None), ('a', None), ('package', None), ('for', None), ('more', None), ('than', None), ('$', None), ('500', None), ('million', None), ('in', None), ('economic', None), ('aid', None), ('for', None), ('Poland', None), ('.', None)]
# [('The', 'DT'), ('plan', 'NN'), ('relies', None), ('heavily', None), ('on', None), ('$', None), ('240', None), ('million', None), ('in', None), ('credit', None), ('and', None), ('loan', None), ('guarantees', None), ('in', None), ('fiscal', None), ('1990', None), ('in', None), ('hopes', None), ('of', None), ('stimulating', None), ('future', None), ('trade', None), ('and', None), ('investment', None), ('.', None)]
# [('South', 'NNP'), ('Africa', None), ('accused', None), ('armed', None), ('Namibian', None), ('nationalist', None), ('guerrillas', None), ('of', None), ('crossing', None), ('from', None), ('bases', None), ('in', None), ('neighboring', None), ('Angola', None), (',', None), ('violating', None), ('U.N.-supervised', None), ('peace', None), ('plans', None), ('for', None), ('the', None), ('territory', None), ("'s", None), ('independence', None), ('from', None), ('Pretoria', None), ('.', None)]
# [('South', 'NNP'), ('African', None), ('troops', None), ('were', None), ('placed', None), ('on', None), ('alert', None), ('.', None)]
# [('Guerrilla', None), ('leaders', None), ('said', None), ('Pretoria', None), ('was', None), ('attempting', None), ('to', None), ('sabotage', None), ('next', None), ('week', None), ("'s", None), ('elections', None), ('in', None), ('Namibia', None), ('.', None)]
# [('Gunmen', None), ('in', None), ('Lebanon', None), ('assassinated', None), ('a', None), ('Saudi', None), ('Arabian', None), ('Embassy', None), ('employee', None), (',', None), ('and', None), ('the', None), ('pro-Iranian', None), ('Islamic', None), ('Jihad', None), ('took', None), ('responsibility', None), ('for', None), ('the', None), ('slaying', None), ('to', None), ('avenge', None), ('the', None), ('beheading', None), ('of', None), ('16', None), ('terrorists', None), ('by', None), ('Riyadh', None), ("'s", None), ('government', None), ('in', None), ('September', None), ('.', None)]
# [('Also', 'RB'), ('in', 'IN'), ('Beirut', None), (',', None), ('a', None), ('Moslem', None), ('group', None), ('vowed', None), ('to', None), ('kill', None), ('Americans', None), ('if', None), ('the', None), ('U.S.', None), ('implements', None), ('a', None), ('policy', None), ('to', None), ('seize', None), ('suspects', None), ('abroad', None), ('.', None)]
# [('Nixon', None), ('concluded', None), ('five', None), ('days', None), ('of', None), ('private', None), ('talks', None), ('with', None), ('Chinese', None), ('leaders', None), ('in', None), ('Beijing', None), (',', None), ('but', None), ('apparently', None), ('failed', None), ('to', None), ('ease', None), ('strains', None), ('in', None), ('Sino-U.S.', None), ('ties', None), ('caused', None), ('by', None), ('China', None), ("'s", None), ('crackdown', None), ('against', None), ('pro-democracy', None), ('protesters', None), ('in', None), ('June', None), ('.', None)]
# [('Beijing', None), ("'s", None), ('rulers', None), ('complained', None), ('to', None), ('the', None), ('former', None), ('president', None), ('about', None), ('U.S.', None), ('``', None), ('interference', None), ("''", None), ('in', None), ('China', None), ("'s", None), ('domestic', None), ('affairs', None), ('.', None)]
# [('Mexico', 'NNP'), ("'s", 'POS'), ('President', None), ('Salinas', None), ('said', None), ('the', None), ('country', None), ("'s", None), ('recession', None), ('had', None), ('ended', None), ('and', None), ('the', None), ('economy', None), ('was', None), ('growing', None), ('again', None), ('.', None)]
# [('In', 'IN'), ('his', 'PRP$'), ('first', 'JJ'), ('state', 'NN'), ('of', 'IN'), ('the', 'DT'), ('nation', 'NN'), ('address', None), (',', None), ('Salinas', None), ('pledged', None), ('to', None), ('continue', None), ('his', None), ('program', None), ('of', None), ('modernization', None), ('and', None), ('warned', None), ('opposition', None), ('politicians', None), ('that', None), ('impeding', None), ('progress', None), ('could', None), ('cost', None), ('them', None), ('popular', None), ('support', None), ('.', None)]
# [('Pakistan', None), ("'s", None), ('Bhutto', None), ('defeated', None), ('the', None), ('first', None), ('no-confidence', None), ('motion', None), ('in', None), ('the', None), ('nation', None), ("'s", None), ('42-year', None), ('history', None), (',', None), ('surviving', None), ('the', None), ('vote', None), ('that', None), ('could', None), ('have', None), ('brought', None), ('down', None), ('her', None), ('11-month-old', None), ('government', None), ('.', None)]
# [('The', 'DT'), ('prime', 'JJ'), ('minister', 'NN'), ("'s", 'POS'), ('opponents', None), ('claimed', None), ('the', None), ('balloting', None), (',', None), ('12', None), ('votes', None), ('short', None), ('of', None), ('a', None), ('majority', None), ('in', None), ('Islamabad', None), ("'s", None), ('237-seat', None), ('assembly', None), (',', None), ('was', None), ('rigged', None), ('.', None)]
# [('The', 'DT'), ('White', 'NNP'), ('House', 'NNP'), ('said', 'VBD'), ('the', 'DT'), ('shipboard', None), ('meetings', None), ('next', None), ('month', None), ('between', None), ('Bush', None), ('and', None), ('Soviet', None), ('leader', None), ('Gorbachev', None), ('will', None), ('take', None), ('place', None), ('in', None), ('the', None), ('waters', None), ('off', None), ('Malta', None), ('.', None)]
# [('The', 'DT'), ('location', None), ('was', None), ('disclosed', None), ('as', None), ('the', None), ('U.S.', None), ('began', None), ('planning', None), ('the', None), ('issues', None), ('to', None), ('be', None), ('discussed', None), ('at', None), ('the', None), ('Dec.', None), ('2-3', None), ('tete-a-tete', None), ('.', None)]
# [('Bush', 'NNP'), ('unveiled', None), ('a', None), ('package', None), ('of', None), ('trade', None), ('initiatives', None), ('to', None), ('help', None), ('establish', None), ('``', None), ('economic', None), ('alternatives', None), ('to', None), ('drug', None), ('trafficking', None), ("''", None), ('in', None), ('the', None), ('Andean', None), ('nations', None), ('of', None), ('South', None), ('America', None), ('.', None)]
# [('The', 'DT'), ('president', 'NN'), ("'s", 'POS'), ('plan', 'NN'), ('includes', 'VBZ'), ('a', 'DT'), ('commitment', None), ('to', None), ('help', None), ('negotiate', None), ('a', None), ('new', None), ('international', None), ('coffee', None), ('agreement', None), ('.', None)]
# [('Pan', None), ('Am', None), ('has', None), ('subpoenaed', None), ('several', None), ('government', None), ('agencies', None), (',', None), ('including', None), ('the', None), ('CIA', None), ('and', None), ('FBI', None), (',', None), ('to', None), ('determine', None), ('whether', None), ('they', None), ('were', None), ('warned', None), ('that', None), ('a', None), ('bomb', None), ('had', None), ('been', None), ('planted', None), ('aboard', None), ('a', None), ('jet', None), ('that', None), ('exploded', None), ('over', None), ('Scotland', None), ('last', None), ('December', None), (',', None), ('killing', None), ('270', None), ('people', None), ('.', None)]
# [('The', 'DT'), ('airline', 'NN'), ('is', 'VBZ'), ('attempting', None), ('to', None), ('show', None), ('that', None), ('Israel', None), ('and', None), ('West', None), ('Germany', None), ('warned', None), ('the', None), ('U.S.', None), ('about', None), ('the', None), ('impending', None), ('attack', None), ('.', None)]
# [('Died', None), (':', None), ('James', None), ('A.', None), ('Attwood', None), (',', None), ('62', None), (',', None), ('retired', None), ('chairman', None), ('and', None), ('president', None), ('of', None), ('Mutual', None), ('Life', None), ('Insurance', None), ('Co.', None), ('of', None), ('New', None), ('York', None), (',', None), ('Tuesday', None), (',', None), ('in', None), ('New', None), ('York', None), ('City', None), (',', None), ('of', None), ('an', None), ('acute', None), ('anemic', None), ('condition', None), ('.', None)]
# [('Sony', None), ('Corp.', None), ('completed', None), ('its', None), ('tender', None), ('offer', None), ('for', None), ('Columbia', None), ('Pictures', None), ('Entertainment', None), ('Inc.', None), (',', None), ('with', None), ('Columbia', None), ('shareholders', None), ('tendering', None), ('99.3', None), ('%', None), ('of', None), ('all', None), ('common', None), ('shares', None), ('outstanding', None), ('by', None), ('the', None), ('Tuesday', None), ('deadline', None), ('.', None)]
# [('Sony', None), ('Columbia', None), ('Acquisition', None), ('Corp.', None), (',', None), ('formed', None), ('for', None), ('the', None), ('Columbia', None), ('deal', None), (',', None), ('will', None), ('formally', None), ('take', None), ('ownership', None), ('of', None), ('the', None), ('movie', None), ('studio', None), ('later', None), ('this', None), ('month', None), (',', None), ('a', None), ('spokesman', None), ('said', None), ('.', None)]
# [('Sony', None), ('is', None), ('paying', None), ('$', None), ('27', None), ('a', None), ('share', None), (',', None), ('or', None), ('$', None), ('3.55', None), ('billion', None), (',', None), ('cash', None), ('and', None), ('is', None), ('assuming', None), ('$', None), ('1.4', None), ('billion', None), ('of', None), ('long-term', None), ('debt', None), ('.', None)]
# [('Still', 'RB'), ('unresolved', None), ('is', None), ('Sony', None), ("'s", None), ('effort', None), ('to', None), ('hire', None), ('producers', None), ('Jon', None), ('Peters', None), ('and', None), ('Peter', None), ('Guber', None), ('to', None), ('run', None), ('the', None), ('studio', None), ('.', None)]
# [('Sony', None), ("'s", None), ('planned', None), ('acquisition', None), ('of', None), ('Guber\\/Peters', None), ('Entertainment', None), ('Co.', None), ('for', None), ('$', None), ('200', None), ('million', None), ('is', None), ('scheduled', None), ('to', None), ('close', None), ('Monday', None), ('.', None)]
# [('Guber\\/Peters', None), ('has', None), ('been', None), ('locked', None), ('in', None), ('litigation', None), ('with', None), ('Warner', None), ('Communications', None), ('Inc.', None), ('in', None), ('an', None), ('attempt', None), ('to', None), ('get', None), ('out', None), ('of', None), ('an', None), ('exclusive', None), ('production', None), ('contract', None), ('with', None), ('Warner', None), ('.', None)]
# [('Both', 'DT'), ('sides', 'NNS'), ('are', 'VBP'), ('in', 'IN'), ('talks', 'NNS'), ('to', 'TO'), ('settle', 'VB'), ('the', 'DT'), ('dispute', 'NN'), ('.', '.')]
# [('Xerox', None), ('Corp.', None), ('has', None), ('told', None), ('employees', None), ('in', None), ('its', None), ('Crum', None), ('&', None), ('Forster', None), ('personal', None), ('insurance', None), ('operations', None), ('that', None), ('it', None), ('is', None), ('laying', None), ('off', None), ('about', None), ('300', None), ('people', None), (',', None), ('or', None), ('25', None), ('%', None), ('of', None), ('the', None), ('staff', None), ('.', None)]
# [('A', 'DT'), ('spokeswoman', 'NN'), ('for', 'IN'), ('Crum', None), ('&', None), ('Forster', None), ('said', None), ('employees', None), ('were', None), ('told', None), ('early', None), ('this', None), ('week', None), ('that', None), ('numerous', None), ('staff', None), ('functions', None), ('for', None), ('the', None), ('personal', None), ('insurance', None), ('lines', None), ('were', None), ('going', None), ('to', None), ('be', None), ('centralized', None), ('as', None), ('a', None), ('cost-cutting', None), ('move', None), ('.', None)]
# [('She', 'PRP'), ('said', 'VBD'), ('the', 'DT'), ('move', 'NN'), ('would', 'MD'), ('result', 'VB'), ('in', 'IN'), ('a', 'DT'), ('after-tax', 'JJ'), ('charge', 'NN'), ('of', 'IN'), ('less', 'JJR'), ('than', 'IN'), ('$', '$'), ('4', 'CD'), ('million', 'CD'), ('to', 'TO'), ('be', 'VB'), ('spread', None), ('over', None), ('the', None), ('next', None), ('three', None), ('quarters', None), ('.', None)]
# [('By', 'IN'), ('comparison', None), (',', None), ('for', None), ('the', None), ('first', None), ('nine', None), ('months', None), (',', None), ('Xerox', None), ('earned', None), ('$', None), ('492', None), ('million', None), (',', None), ('or', None), ('$', None), ('4.55', None), ('a', None), ('share', None), (',', None), ('on', None), ('revenue', None), ('of', None), ('$', None), ('12.97', None), ('billion', None), ('.', None)]
# [('Earnings', 'NNS'), ('at', 'IN'), ('Xerox', None), ("'s", None), ('financial-services', None), ('operations', None), ('actually', None), ('rose', None), ('slightly', None), (',', None), ('but', None), ('that', None), ('was', None), ('largely', None), ('because', None), ('capital', None), ('gains', None), ('at', None), ('Crum', None), ('&', None), ('Forster', None), ('offset', None), ('Hurricane', None), ('Hugo', None), ('payments', None), ('and', None), ('the', None), ('reserves', None), ('set', None), ('up', None), ('to', None), ('cover', None), ('future', None), ('payments', None), ('.', None)]
# [('Property\\/casualty', None), ('insurance', None), ('has', None), ('been', None), ('a', None), ('tough', None), ('business', None), ('in', None), ('recent', None), ('quarters', None), (',', None), ('as', None), ('pricing', None), ('has', None), ('been', None), ('cutthroat', None), ('and', None), ('natural', None), ('disasters', None), ('such', None), ('as', None), ('Hurricane', None), ('Hugo', None), ('and', None), ('the', None), ('California', None), ('earthquake', None), ('have', None), ('resulted', None), ('in', None), ('huge', None), ('payments', None), ('.', None)]
# [('Komatsu', None), ('Ltd.', None), (',', None), ('a', None), ('large', None), ('integrated', None), ('maker', None), ('of', None), ('construction', None), ('machinery', None), (',', None), ('posted', None), ('a', None), ('32', None), ('%', None), ('unconsolidated', None), ('gain', None), ('in', None), ('first-half', None), ('pretax', None), ('profit', None), ('.', None)]
# [('For', 'IN'), ('the', 'DT'), ('period', 'NN'), ('ended', 'VBD'), ('Sept.30', None), (',', None), ('it', None), ('earned', None), ('16.68', None), ('billion', None), ('yen', None), (',', None), ('-LRB-', None), ('US$', None), ('116.7', None), ('million', None), ('-RRB-', None), ('up', None), ('from', None), ('12.68', None), ('billion', None), ('yen', None), ('the', None), ('year', None), ('before', None), ('.', None)]
# [('Sales', 'NNS'), ('rose', 'VBD'), ('11', 'CD'), ('%', 'NN'), ('to', 'TO'), ('292.32', None), ('billion', None), ('yen', None), ('from', None), ('263.07', None), ('billion', None), ('yen', None), ('.', None)]
# [('Net', 'JJ'), ('income', 'NN'), ('surged', 'VBD'), ('31', None), ('%', None), ('to', None), ('7.63', None), ('billion', None), ('yen', None), ('from', None), ('5.82', None), ('billion', None), ('yen', None), ('.', None)]
# [('Per-share', None), ('net', None), ('rose', None), ('to', None), ('7.84', None), ('yen', None), ('from', None), ('6.53', None), ('yen', None), ('.', None)]
# [('Brisk', None), ('domestic', None), ('demand', None), ('due', None), ('to', None), ('increasing', None), ('capital', None), ('investment', None), ('pushed', None), ('up', None), ('sales', None), ('sharply', None), ('in', None), ('construction', None), ('and', None), ('industrial', None), ('machinery', None), ('divisions', None), ('.', None)]
# [('Domestic', None), ('sales', None), ('of', None), ('construction', None), ('machinery', None), (',', None), ('such', None), ('as', None), ('power', None), ('shovels', None), ('and', None), ('bulldozers', None), ('rose', None), ('to', None), ('142.84', None), ('billion', None), ('yen', None), ('from', None), ('126.15', None), ('billion', None), ('yen', None), ('.', None)]
# [('Demand', None), ('from', None), ('Europe', None), ('and', None), ('Southeast', None), ('Asia', None), ('also', None), ('grew', None), (',', None), ('but', None), ('due', None), ('to', None), ('increasing', None), ('production', None), ('at', None), ('local', None), ('plants', None), (',', None), ('overseas', None), ('sales', None), ('edged', None), ('down', None), ('2.8', None), ('%', None), ('.', None)]
# [('Komatsu', None), ('predicted', None), ('that', None), ('for', None), ('the', None), ('fiscal', None), ('year', None), ('ending', None), ('March', None), ('31', None), ('sales', None), ('will', None), ('climb', None), ('to', None), ('600', None), ('billion', None), ('yen', None), ('from', None), ('566.54', None), ('billion', None), ('yen', None), (';', None), ('pretax', None), ('profit', None), ('was', None), ('forecast', None), ('at', None), ('35', None), ('billion', None), ('yen', None), (',', None), ('up', None), ('from', None), ('28.53', None), ('billion', None), ('yen', None), ('in', None), ('fiscal', None), ('1989', None), ('.', None)]
# [('Net', 'JJ'), ('is', 'VBZ'), ('expected', 'VBN'), ('to', 'TO'), ('rise', 'VB'), ('to', 'TO'), ('17', 'CD'), ('billion', 'CD'), ('yen', 'NN'), ('from', 'IN'), ('12.82', None), ('billion', None), ('yen', None), ('a', None), ('year', None), ('earlier', None), ('.', None)]
# [('ECONOMIC', None), ('GROWTH', None), ('APPEARS', None), ('to', None), ('be', None), ('leveling', None), ('off', None), (',', None), ('latest', None), ('reports', None), ('suggest', None), ('.', None)]
# [('Factory', 'NN'), ('orders', 'NNS'), ('and', 'CC'), ('construction', 'NN'), ('outlays', None), ('were', None), ('largely', None), ('flat', None), ('in', None), ('September', None), (',', None), ('while', None), ('purchasing', None), ('agents', None), ('said', None), ('manufacturing', None), ('shrank', None), ('further', None), ('in', None), ('October', None), ('.', None)]
# [('Still', 'RB'), (',', ','), ('many', 'JJ'), ('economists', 'NNS'), ('are', 'VBP'), ("n't", 'RB'), ('predicting', 'VBG'), ('a', 'DT'), ('recession', 'NN'), ('anytime', None), ('soon', None), ('.', None)]
# [('The', 'DT'), ('Fed', 'NNP'), ('is', 'VBZ'), ('coming', 'VBG'), ('under', 'IN'), ('pressure', 'NN'), ('to', 'TO'), ('cut', 'VB'), ('short-term', 'JJ'), ('interest', 'NN'), ('rates', 'NNS'), ('due', 'JJ'), ('to', 'TO'), ('the', 'DT'), ('apparent', None), ('slowing', None), ('of', None), ('the', None), ('economy', None), ('.', None)]
# [('But', 'CC'), ('it', 'PRP'), ('is', 'VBZ'), ("n't", 'RB'), ('clear', 'JJ'), ('yet', None), ('whether', None), ('the', None), ('central', None), ('bank', None), ('will', None), ('make', None), ('such', None), ('a', None), ('move', None), ('.', None)]
# [('Campbell', 'NNP'), ('Soup', 'NNP'), ('forced', None), ('out', None), ('its', None), ('president', None), ('and', None), ('chief', None), ('executive', None), (',', None), ('R.', None), ('Gordon', None), ('McGovern', None), (',', None), ('the', None), ('strongest', None), ('indication', None), ('yet', None), ('that', None), ('the', None), ('Dorrance', None), ('family', None), ('plans', None), ('to', None), ('take', None), ('charge', None), ('of', None), ('reshaping', None), ('the', None), ('troubled', None), ('food', None), ('company', None), ('.', None)]
# [('Campbell', 'NNP'), ("'s", 'POS'), ('stock', 'NN'), ('rose', 'VBD'), ('$', '$'), ('3.375', 'CD'), (',', ','), ('to', 'TO'), ('$', '$'), ('47.125', 'CD'), (',', ','), ('in', 'IN'), ('reaction', None), ('.', None)]
# [('The', 'DT'), ('Chicago', 'NNP'), ('Merc', 'NNP'), ('plans', 'VBZ'), ('an', 'DT'), ('additional', 'JJ'), ('``', '``'), ('circuit', 'NN'), ('breaker', 'NN'), ("''", "''"), ('to', 'TO'), ('stem', None), ('sharp', None), ('drops', None), ('in', None), ('the', None), ('market', None), ('.', None)]
# [('Also', 'RB'), (',', ','), ('Big', 'NNP'), ('Board', 'NNP'), ('Chairman', 'NNP'), ('Phelan', 'NNP'), ('said', 'VBD'), ('he', 'PRP'), ('would', 'MD'), ('support', 'VB'), ('SEC', None), ('halts', None), ('of', None), ('program', None), ('trading', None), ('during', None), ('market', None), ('crises', None), ('but', None), ('not', None), ('any', None), ('revival', None), ('of', None), ('a', None), ('``', None), ('collar', None), ("''", None), ('on', None), ('trading', None), ('.', None)]
# [('Georgia', 'NNP'), ('Gulf', 'NNP'), ('received', 'VBD'), ('a', 'DT'), ('new', 'JJ'), ('takeover', 'NN'), ('bid', 'NN'), ('from', 'IN'), ('investor', 'NN'), ('Harold', 'NNP'), ('Simmons', 'NNP'), ('and', 'CC'), ('NL', 'NNP'), ('Industries', 'NNPS'), ('of', 'IN'), ('$', '$'), ('50', 'CD'), ('a', 'DT'), ('share', 'NN'), (',', ','), ('or', 'CC'), ('about', 'IN'), ('$', '$'), ('1.1', 'CD'), ('billion', 'CD'), ('.', '.')]
# [('The', 'DT'), ('offer', 'NN'), (',', ','), ('which', 'WDT'), ('follows', None), ('a', None), ('$', None), ('55-a-share', None), ('bid', None), ('that', None), ('was', None), ('rejected', None), ('in', None), ('September', None), (',', None), ('steps', None), ('up', None), ('pressure', None), ('on', None), ('the', None), ('chemicals', None), ('concern', None), ('.', None)]
# [('The', 'DT'), ('minimum-wage', None), ('bill', None), ('worked', None), ('out', None), ('by', None), ('Congress', None), ('and', None), ('Bush', None), ('won', None), ('easy', None), ('approval', None), ('in', None), ('the', None), ('House', None), ('.', None)]
# [('The', 'DT'), ('compromise', 'NN'), ('plan', 'NN'), (',', ','), ('which', 'WDT'), ('boosts', 'VBZ'), ('the', 'DT'), ('minimum', 'JJ'), ('wage', 'NN'), ('for', 'IN'), ('the', 'DT'), ('first', 'JJ'), ('time', 'NN'), ('since', 'IN'), ('1981', 'CD'), (',', ','), ('is', 'VBZ'), ('expected', 'VBN'), ('to', 'TO'), ('clear', None), ('the', None), ('Senate', None), ('soon', None), ('.', None)]
# [('Steinberg', None), ('sought', None), ('clearance', None), ('to', None), ('buy', None), ('more', None), ('than', None), ('15', None), ('%', None), ('of', None), ('United', None), ('Air', None), ("'s", None), ('parent', None), (',', None), ('saying', None), ('he', None), ('may', None), ('seek', None), ('control', None), ('.', None)]
# [('Takeover', 'NN'), ('experts', 'NNS'), ('said', 'VBD'), ('they', 'PRP'), ('doubted', 'VBD'), ('the', 'DT'), ('financier', None), ('would', None), ('make', None), ('a', None), ('bid', None), ('by', None), ('himself', None), ('.', None)]
# [('An', 'DT'), ('airline', 'NN'), ('buy-out', 'NN'), ('bill', 'NN'), ('was', 'VBD'), ('approved', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('House', 'NNP'), ('.', '.')]
# [('The', 'DT'), ('measure', 'NN'), ('would', 'MD'), ('make', 'VB'), ('it', 'PRP'), ('easier', 'JJR'), ('for', 'IN'), ('the', 'DT'), ('Transportation', 'NNP'), ('Department', 'NNP'), ('to', 'TO'), ('block', 'VB'), ('leveraged', None), ('buy-outs', None), ('in', None), ('the', None), ('industry', None), ('.', None)]
# [('USX', 'NNP'), ('was', 'VBD'), ('cited', None), ('by', None), ('OSHA', None), ('for', None), ('several', None), ('health', None), ('and', None), ('safety', None), ('violations', None), ('at', None), ('two', None), ('Pennsylvania', None), ('plants', None), ('and', None), ('may', None), ('face', None), ('a', None), ('record', None), ('fine', None), ('of', None), ('$', None), ('7.3', None), ('million', None), ('.', None)]
# [('Random', None), ('House', None), ('Chairman', None), ('Robert', None), ('Bernstein', None), ('said', None), ('he', None), ('is', None), ('resigning', None), ('from', None), ('the', None), ('publishing', None), ('house', None), ('he', None), ('has', None), ('run', None), ('for', None), ('23', None), ('years', None), ('.', None)]
# [('A', 'DT'), ('successor', 'NN'), ('was', 'VBD'), ("n't", 'RB'), ('named', 'VBN'), ('.', '.')]
# [('Cray', 'NNP'), ('Research', 'NNP'), ('indicated', None), ('that', None), ('the', None), ('survival', None), ('of', None), ('a', None), ('spinoff', None), ('company', None), (',', None), ('which', None), ('is', None), ('developing', None), ('a', None), ('new', None), ('supercomputer', None), (',', None), ('depends', None), ('heavily', None), ('on', None), ('its', None), ('chairman', None), ('and', None), ('chief', None), ('designer', None), (',', None), ('Seymour', None), ('Cray', None), ('.', None)]
# [('Light', None), ('trucks', None), ('and', None), ('vans', None), ('will', None), ('face', None), ('the', None), ('same', None), ('safety', None), ('requirements', None), ('as', None), ('automobiles', None), ('under', None), ('new', None), ('proposals', None), ('by', None), ('the', None), ('Transportation', None), ('Department', None), ('.', None)]
# [('The', 'DT'), ('Treasury', 'NNP'), ('plans', 'VBZ'), ('to', 'TO'), ('sell', 'VB'), ('$', '$'), ('30', 'CD'), ('billion', 'CD'), ('in', 'IN'), ('notes', 'NNS'), ('and', 'CC'), ('bonds', 'NNS'), ('next', 'IN'), ('week', 'NN'), ('but', 'CC'), ('will', 'MD'), ('delay', None), ('the', None), ('auction', None), ('unless', None), ('Congress', None), ('quickly', None), ('raises', None), ('the', None), ('debt', None), ('ceiling', None), ('.', None)]
# [('U.S.', 'NNP'), ('farmers', None), ("'", None), ('net', None), ('income', None), ('rose', None), ('to', None), ('a', None), ('record', None), ('$', None), ('59.9', None), ('billion', None), ('last', None), ('year', None), ('despite', None), ('one', None), ('of', None), ('the', None), ('worst', None), ('droughts', None), ('ever', None), ('.', None)]
# [('Two', 'CD'), ('antitrust', None), ('agencies', None), ('may', None), ('face', None), ('further', None), ('cutbacks', None), ('because', None), ('of', None), ('a', None), ('complicated', None), ('new', None), ('funding', None), ('device', None), (',', None), ('some', None), ('Democrats', None), ('in', None), ('Congress', None), ('are', None), ('warning', None), ('.', None)]
# [('Markets', None), ('--', None), ('Stocks', None), (':', None), ('Volume', None), ('154,240,000', None), ('shares', None), ('.', None)]
# [('Dow', 'NNP'), ('Jones', 'NNP'), ('industrials', 'NNS'), ('2645.90', None), (',', None), ('up', None), ('0.82', None), (';', None), ('transportation', None), ('1206.26', None), (',', None), ('up', None), ('1.25', None), (';', None), ('utilities', None), ('220.45', None), (',', None), ('up', None), ('1.26', None), ('.', None)]
# [('Bonds', 'NNS'), (':', ':'), ('Shearson', None), ('Lehman', None), ('Hutton', None), ('Treasury', None), ('index', None), ('3436.58', None), (',', None), ('up', None), ('Commodities', None), (':', None), ('Dow', None), ('Jones', None), ('futures', None), ('index', None), ('129.91', None), (',', None), ('up', None), ('0.28', None), (';', None), ('spot', None), ('index', None), ('131.01', None), (',', None), ('up', None), ('1.17', None), ('.', None)]
# [('Dollar', None), (':', None), ('143.80', None), ('yen', None), (',', None), ('up', None), ('0.95', None), (';', None), ('1.8500', None), ('marks', None), (',', None), ('up', None), ('0.0085', None), ('.', None)]
# [('Junk-bond', None), ('markdowns', None), (',', None), ('an', None), ('ongoing', None), ('Securities', None), ('and', None), ('Exchange', None), ('Commission', None), ('investigation', None), (',', None), ('a', None), ('Drexel', None), ('Burnham', None), ('Lambert', None), ('connection', None), (',', None), ('a', None), ('fizzled', None), ('buy-out', None), ('rumor', None), ('.', None)]
# [('All', 'DT'), ('this', None), ('has', None), ('cast', None), ('a', None), ('pall', None), ('over', None), ('Columbia', None), ('Savings', None), ('&', None), ('Loan', None), ('Association', None), ('and', None), ('its', None), ('high-rolling', None), ('43-year-old', None), ('chairman', None), (',', None), ('Thomas', None), ('Spiegel', None), (',', None), ('who', None), ('built', None), ('the', None), ('$', None), ('12.7', None), ('billion', None), ('Beverly', None), ('Hills', None), (',', None), ('Calif.', None), (',', None), ('thrift', None), ('with', None), ('high-yield', None), ('junk', None), ('bonds', None), ('.', None)]
# [('Bears', None), ('have', None), ('targeted', None), ('Columbia', None), ("'s", None), ('stock', None), ('because', None), ('of', None), ('the', None), ('thrift', None), ("'s", None), ('exposure', None), ('to', None), ('the', None), ('shaky', None), ('junk', None), ('market', None), ('.', None)]
# [('And', 'CC'), ('some', 'DT'), ('investors', 'NNS'), ('fault', None), ('Mr.', None), ('Spiegel', None), ("'s", None), ('life', None), ('style', None), (';', None), ('he', None), ('earns', None), ('millions', None), ('of', None), ('dollars', None), ('a', None), ('year', None), ('and', None), ('flies', None), ('around', None), ('in', None), ('Columbia', None), ("'s", None), ('jet', None), ('planes', None), ('.', None)]
# [('Columbia', None), ('stock', None), ('recently', None), ('hit', None), ('4', None), ('1\\/8', None), (',', None), ('after', None), ('reaching', None), ('11', None), ('3\\/4', None), ('earlier', None), ('this', None), ('year', None), ('on', None), ('rumors', None), ('that', None), ('Mr.', None), ('Spiegel', None), ('would', None), ('take', None), ('the', None), ('thrift', None), ('private', None), ('.', None)]
# [('Moreover', 'RB'), (',', ','), ('junk', None), ('professionals', None), ('think', None), ('Columbia', None), ("'s", None), ('huge', None), ('third-quarter', None), ('markdown', None), ('of', None), ('its', None), ('junk', None), ('portfolio', None), ('to', None), ('$', None), ('4.4', None), ('billion', None), ('was', None), ("n't", None), ('enough', None), (',', None), ('meaning', None), ('another', None), ('markdown', None), ('could', None), ('be', None), ('coming', None), ('.', None)]
# [('But', 'CC'), ('in', 'IN'), ('recent', 'JJ'), ('days', 'NNS'), (',', ','), ('Columbia', None), ('has', None), ('edged', None), ('up', None), (',', None), ('closing', None), ('at', None), ('5', None), ('1\\/4', None), (',', None), ('up', None), ('3\\/8', None), (',', None), ('yesterday', None), ('on', None), ('revived', None), ('speculation', None), ('that', None), ('the', None), ('thrift', None), ('might', None), ('restructure', None), ('.', None)]
# [('Mr.', 'NNP'), ('Spiegel', None), ("'s", None), ('fans', None), ('say', None), ('Columbia', None), ("'s", None), ('Southern', None), ('California', None), ('branches', None), ('are', None), ('highly', None), ('salable', None), (',', None), ('and', None), ('the', None), ('thrift', None), ('has', None), ('$', None), ('458', None), ('million', None), ('of', None), ('shareholders', None), ('equity', None), ('underlying', None), ('its', None), ('assets', None), ('.', None)]
# [('That', 'DT'), ("'s", 'VBZ'), ('almost', 'RB'), ('$', '$'), ('10', 'CD'), ('of', 'IN'), ('equity', 'NN'), ('for', 'IN'), ('each', 'DT'), ('Columbia', None), ('share', None), (',', None), ('including', None), ('convertible', None), ('preferred', None), ('shares', None), (',', None), ('though', None), ('more', None), ('junk', None), ('markdowns', None), ('would', None), ('reduce', None), ('the', None), ('cushion', None), ('.', None)]
# [('Columbia', None), ('has', None), ('only', None), ('about', None), ('10', None), ('million', None), ('common', None), ('shares', None), ('in', None), ('public', None), ('hands', None), ('.', None)]
# [('The', 'DT'), ('Spiegel', None), ('family', None), ('has', None), ('25', None), ('%', None), ('of', None), ('the', None), ('common', None), ('and', None), ('75', None), ('%', None), ('of', None), ('the', None), ('votes', None), ('.', None)]
# [('Other', 'JJ'), ('big', 'JJ'), ('common', None), ('holders', None), ('are', None), ('Carl', None), ('Lindner', None), ("'s", None), ('American', None), ('Financial', None), (',', None), ('investor', None), ('Irwin', None), ('Jacobs', None), ('and', None), ('Pacific', None), ('Financial', None), ('Research', None), (',', None), ('though', None), ('the', None), ('latter', None), ('cut', None), ('its', None), ('stake', None), ('this', None), ('summer', None), ('.', None)]
# [('While', 'IN'), ('many', 'JJ'), ('problems', 'NNS'), ('would', 'MD'), ('attend', None), ('a', None), ('restructuring', None), ('of', None), ('Columbia', None), (',', None), ('investors', None), ('say', None), ('Mr.', None), ('Spiegel', None), ('is', None), ('mulling', None), ('such', None), ('a', None), ('plan', None), ('to', None), ('mitigate', None), ('Columbia', None), ("'s", None), ('junk', None), ('problems', None), ('.', None)]
# [('Indeed', 'RB'), (',', ','), ('Columbia', None), ('executives', None), ('recently', None), ('told', None), ('reporters', None), ('they', None), ('were', None), ('interested', None), ('in', None), ('creating', None), ('a', None), ('separate', None), ('unit', None), ('to', None), ('hold', None), ('Columbia', None), ("'s", None), ('junk', None), ('bonds', None), ('and', None), ('perhaps', None), ('do', None), ('merchant', None), ('banking', None), ('.', None)]
# [('Columbia', None), ('wo', None), ("n't", None), ('comment', None), ('on', None), ('all', None), ('the', None), ('speculation', None), ('.', None)]
# [('But', 'CC'), ('like', 'IN'), ('other', 'JJ'), ('thrifts', None), (',', None), ('it', None), ("'s", None), ('expected', None), ('to', None), ('seek', None), ('regulators', None), ("'", None), ('consent', None), ('to', None), ('create', None), ('a', None), ('distinct', None), ('junk-bond', None), ('entity', None), ('.', None)]
# [('Plans', 'NNS'), ('to', 'TO'), ('do', 'VB'), ('this', 'DT'), ('are', 'VBP'), ('due', 'JJ'), ('to', 'TO'), ('be', 'VB'), ('filed', None), ('in', None), ('a', None), ('week', None), ('or', None), ('so', None), ('.', None)]
# [('New', 'NNP'), ('rules', None), ('force', None), ('thrifts', None), ('to', None), ('write', None), ('down', None), ('their', None), ('junk', None), ('to', None), ('market', None), ('value', None), (',', None), ('then', None), ('sell', None), ('the', None), ('bonds', None), ('over', None), ('five', None), ('years', None), ('.', None)]
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('Columbia', None), ('just', None), ('wrote', None), ('off', None), ('$', None), ('130', None), ('million', None), ('of', None), ('its', None), ('junk', None), ('and', None), ('reserved', None), ('$', None), ('227', None), ('million', None), ('for', None), ('future', None), ('junk', None), ('losses', None), ('.', None)]
# [('But', 'CC'), ('if', 'IN'), ('Columbia', 'NNP'), ('could', 'MD'), ('keep', None), ('its', None), ('junk', None), ('bonds', None), ('separate', None), ('from', None), ('the', None), ('thrift', None), ('till', None), ('they', None), ('mature', None), ('--', None), ('at', None), ('full', None), ('value', None), (',', None), ('unless', None), ('the', None), ('issuer', None), ('goes', None), ('bust', None), ('or', None), ('restructures', None), ('--', None), ('the', None), ('junk', None), ('portfolio', None), ('might', None), ('do', None), ('all', None), ('right', None), ('.', None)]
# [('Columbia', None), (',', None), ('a', None), ('longtime', None), ('Drexel', None), ('client', None), (',', None), ('wo', None), ("n't", None), ('provide', None), ('current', None), ('data', None), ('on', None), ('its', None), ('junk', None), ('.', None)]
# [('But', 'CC'), ('its', 'PRP$'), ('17', None), ('big', None), ('junk', None), ('holdings', None), ('at', None), ('year', None), ('end', None), ('showed', None), ('only', None), ('a', None), ('few', None), ('bonds', None), ('that', None), ('have', None), ('been', None), ('really', None), ('battered', None), ('.', None)]
# ...
# [('The', 'DT'), ('company', 'NN'), ('attributed', None), ('lower', None), ('sales', None), ('and', None), ('earnings', None), ('for', None), ('the', None), ('steel', None), ('segment', None), ('to', None), ('the', None), ('loss', None), ('of', None), ('results', None), ('from', None), ('the', None), ('Lorain', None), (',', None), ('Ohio', None), (',', None), ('plant', None), (',', None), ('which', None), ('now', None), ('is', None), ('a', None), ('50-50', None), ('joint', None), ('venture', None), ('with', None), ('Japan', None), ("'s", None), ('Kobe', None), ('Steel', None), ('Ltd', None), ('.', None)]
# [('In', 'IN'), ('the', 'DT'), ('steel', 'NN'), ('division', 'NN'), (',', ','), ('operating', 'VBG'), ('profit', None), ('dropped', None), ('11', None), ('%', None), ('to', None), ('$', None), ('85', None), ('million', None), ('.', None)]
# [('Profit', 'NN'), ('per', None), ('ton', None), ('of', None), ('steel', None), ('shipped', None), ('dropped', None), ('to', None), ('about', None), ('$', None), ('33', None), ('a', None), ('ton', None), ('from', None), ('$', None), ('42', None), ('a', None), ('ton', None), ('last', None), ('year', None), ('and', None), ('$', None), ('53', None), ('a', None), ('ton', None), ('in', None), ('the', None), ('second', None), ('quarter', None), (',', None), ('analysts', None), ('said', None), ('.', None)]
# [('Still', 'RB'), (',', ','), ('USX', None), ('fared', None), ('better', None), ('than', None), ('other', None), ('major', None), ('steelmakers', None), (',', None), ('earning', None), ('more', None), ('per', None), ('ton', None), ('of', None), ('steel', None), ('shipped', None), ('than', None), ('either', None), ('Bethlehem', None), ('Steel', None), ('Corp.', None), (',', None), ('which', None), ('posted', None), ('a', None), ('54', None), ('%', None), ('drop', None), ('in', None), ('net', None), ('income', None), (',', None), ('or', None), ('Inland', None), ('Steel', None), ('Industries', None), ('Inc.', None), (',', None), ('whose', None), ('profit', None), ('plummeted', None), ('70', None), ('%', None), ('.', None)]
# [('In', 'IN'), ('New', 'NNP'), ('York', 'NNP'), ('Stock', 'NNP'), ('Exchange', 'NNP'), ('composite', 'JJ'), ('trading', 'NN'), ('yesterday', 'NN'), (',', ','), ('USX', None), ('shares', None), ('closed', None), ('up', None), ('$', None), ('1.25', None), (',', None), ('at', None), ('$', None), ('34.625', None), (',', None), ('as', None), ('the', None), ('reported', None), ('earnings', None), ('exceeded', None), ('projections', None), ('by', None), ('some', None), ('analysts', None), ('who', None), ('had', None), ("n't", None), ('expected', None), ('as', None), ('great', None), ('a', None), ('volume', None), ('of', None), ('asset', None), ('sales', None), ('.', None)]
# [('The', 'DT'), ('rise', 'NN'), ('in', 'IN'), ('the', 'DT'), ('stock', 'NN'), ("'s", 'POS'), ('price', 'NN'), ('may', 'MD'), ('also', 'RB'), ('reflect', None), ('the', None), ('fact', None), ('that', None), ('USX', None), ("'s", None), ('steel', None), ('segment', None), ('fared', None), ('better', None), ('than', None), ('some', None), ('other', None), ('steelmakers', None), ("'", None), ('.', None)]
# [('Charles', 'NNP'), ('Bradford', None), (',', None), ('an', None), ('analyst', None), ('with', None), ('Merrill', None), ('Lynch', None), ('Capital', None), ('Markets', None), (',', None), ('said', None), ('USX', None), ('may', None), ('have', None), ('received', None), ('orders', None), ('lost', None), ('by', None), ('competitors', None), ('who', None), ('were', None), ('involved', None), ('in', None), ('labor', None), ('contracts', None), ('earlier', None), ('this', None), ('year', None), ('.', None)]
# [('He', 'PRP'), ('said', 'VBD'), ('USX', 'NNP'), ('also', 'RB'), ('appeared', None), ('to', None), ('sell', None), ('a', None), ('richer', None), ('mix', None), ('of', None), ('steel', None), ('products', None), (',', None), ('such', None), ('as', None), ('the', None), ('more', None), ('profitable', None), ('pipe', None), ('and', None), ('galvanized', None), ('coated', None), ('sheet', None), (',', None), ('than', None), ('lower-priced', None), ('structural', None), ('goods', None), ('.', None)]
# [('The', 'DT'), ('energy', 'NN'), ('segment', 'NN'), (',', ','), ('with', 'IN'), ('a', 'DT'), ('15', 'CD'), ('%', 'NN'), ('rise', 'NN'), ('in', 'IN'), ('operating', 'NN'), ('profit', 'NN'), (',', ','), ('is', 'VBZ'), ('clearly', 'RB'), ('the', 'DT'), ('company', 'NN'), ("'s", 'POS'), ('strongest', None), ('.', None)]
# [('Higher', 'JJR'), ('crude', None), ('oil', None), ('prices', None), ('helped', None), ('boost', None), ('operating', None), ('profit', None), ('for', None), ('the', None), ('Marathon', None), ('Oil', None), ('Co.', None), ('unit', None), ('to', None), ('$', None), ('198', None), ('million', None), ('from', None), ('$', None), ('180', None), ('million', None), ('.', None)]
# [('The', 'DT'), ('Texas', 'NNP'), ('Oil', 'NNP'), ('&', 'CC'), ('Gas', None), ('division', None), ('continues', None), ('to', None), ('operate', None), ('in', None), ('the', None), ('red', None), (',', None), ('although', None), ('losses', None), ('narrowed', None), ('to', None), ('$', None), ('9', None), ('million', None), ('from', None), ('$', None), ('15', None), ('million', None), ('.', None)]
# [('USX', 'NNP'), ('announced', 'VBD'), ('in', 'IN'), ('October', 'NNP'), ('that', 'IN'), ('it', 'PRP'), ('was', 'VBD'), ('soliciting', None), ('bids', None), ('to', None), ('sell', None), ('TXO', None), ("'s", None), ('oil', None), ('and', None), ('gas', None), ('reserves', None), ('.', None)]
# [('Proceeds', None), ('of', None), ('that', None), ('sale', None), ('are', None), ('to', None), ('be', None), ('used', None), ('to', None), ('reduce', None), ('debt', None), ('and', None), ('buy', None), ('back', None), ('shares', None), ('.', None)]
# [('The', 'DT'), ('company', 'NN'), ('noted', 'VBD'), ('that', 'IN'), ('it', 'PRP'), ('has', 'VBZ'), ('reduced', None), ('debt', None), ('by', None), ('$', None), ('1.6', None), ('billion', None), ('since', None), ('the', None), ('end', None), ('of', None), ('1988', None), ('and', None), ('bought', None), ('back', None), ('about', None), ('15.5', None), ('million', None), ('shares', None), ('of', None), ('common', None), ('stock', None), ('since', None), ('the', None), ('fourth', None), ('quarter', None), ('of', None), ('1987', None), ('.', None)]
# [('USX', 'NNP'), ('has', 'VBZ'), ('about', 'IN'), ('$', '$'), ('5.5', 'CD'), ('billion', 'CD'), ('in', 'IN'), ('long-term', 'JJ'), ('debt', 'NN'), ('and', 'CC'), ('257', None), ('million', None), ('shares', None), ('outstanding', None), ('.', None)]
# [('The', 'DT'), ('announced', None), ('sale', None), ('of', None), ('the', None), ('reserves', None), ('was', None), ('followed', None), ('by', None), ('news', None), ('that', None), ('investor', None), ('Carl', None), ('Icahn', None), ('had', None), ('increased', None), ('his', None), ('stake', None), ('in', None), ('USX', None), ('to', None), ('13.1', None), ('%', None), ('and', None), ('threatened', None), ('a', None), ('takeover', None), ('or', None), ('other', None), ('business', None), ('combination', None), ('.', None)]
# [('Mr.', 'NNP'), ('Icahn', None), ('has', None), ('said', None), ('he', None), ('believes', None), ('USX', None), ('would', None), ('be', None), ('worth', None), ('more', None), ('if', None), ('broken', None), ('up', None), ('into', None), ('steel', None), ('and', None), ('energy', None), ('segments', None), ('.', None)]
# [('Profit', 'NN'), ('for', 'IN'), ('the', 'DT'), ('nine', 'CD'), ('months', 'NNS'), ('jumped', None), ('21', None), ('%', None), ('to', None), ('$', None), ('721', None), ('million', None), (',', None), ('or', None), ('$', None), ('2.62', None), ('a', None), ('share', None), (',', None), ('from', None), ('$', None), ('598', None), ('million', None), (',', None), ('or', None), ('$', None), ('2.07', None), ('a', None), ('share', None), ('.', None)]
# [('Sales', 'NNS'), ('rose', 'VBD'), ('10', 'CD'), ('%', 'NN'), ('to', 'TO'), ('$', '$'), ('13.8', 'CD'), ('billion', 'CD'), ('from', 'IN'), ('$', '$'), ('12.5', None), ('billion', None), ('.', None)]
# [('John', 'NNP'), ('F.', 'NNP'), ('Barrett', None), (',', None), ('40', None), (',', None), ('formerly', None), ('executive', None), ('vice', None), ('president', None), ('and', None), ('chief', None), ('financial', None), ('officer', None), (',', None), ('was', None), ('named', None), ('president', None), ('and', None), ('chief', None), ('operating', None), ('officer', None), (',', None), ('posts', None), ('which', None), ('had', None), ('been', None), ('vacant', None), ('.', None)]
# [('Leon', None), ('J.', None), ('Level', None), (',', None), ('vice', None), ('president', None), ('and', None), ('chief', None), ('financial', None), ('officer', None), ('of', None), ('this', None), ('computer', None), ('services', None), ('concern', None), (',', None), ('and', None), ('F.', None), ('Warren', None), ('McFarlan', None), (',', None), ('a', None), ('professor', None), ('at', None), ('Harvard', None), ('University', None), ("'s", None), ('Graduate', None), ('School', None), ('of', None), ('Business', None), (',', None), ('were', None), ('elected', None), ('directors', None), (',', None), ('increasing', None), ('board', None), ('membership', None), ('to', None), ('nine', None), ('.', None)]
# [('David', 'NNP'), ('A.', 'NNP'), ('DiLoreto', None), (',', None), ('president', None), ('of', None), ('metal', None), ('container', None), ('division', None), (',', None), ('was', None), ('named', None), ('to', None), ('the', None), ('additional', None), ('post', None), ('of', None), ('group', None), ('vice', None), ('president', None), (',', None), ('packaging', None), ('products', None), (',', None), ('at', None), ('this', None), ('packaging', None), (',', None), ('industrial', None), ('and', None), ('aerospace', None), ('products', None), ('concern', None), (',', None), ('succeeding', None), ('Delmont', None), ('A.', None), ('Davis', None), (',', None), ('who', None), ('was', None), ('named', None), ('president', None), ('and', None), ('chief', None), ('operating', None), ('officer', None), ('in', None), ('August', None), ('.', None)]
# [('Two', 'CD'), ('leading', 'VBG'), ('constitutional-law', None), ('experts', None), ('said', None), ('President', None), ('Bush', None), ('does', None), ("n't", None), ('have', None), ('the', None), ('legal', None), ('authority', None), ('to', None), ('exercise', None), ('a', None), ('line-item', None), ('veto', None), ('.', None)]
# [('Professors', None), ('Philip', None), ('Kurland', None), ('of', None), ('the', None), ('University', None), ('of', None), ('Chicago', None), ('and', None), ('Laurence', None), ('Tribe', None), ('of', None), ('Harvard', None), ('Law', None), ('School', None), ('said', None), ('any', None), ('effort', None), ('by', None), ('President', None), ('Bush', None), ('to', None), ('claim', None), ('authority', None), ('for', None), ('a', None), ('line-item', None), ('veto', None), ('would', None), ('contradict', None), ('the', None), ('text', None), ('of', None), ('the', None), ('Constitution', None), ('and', None), ('the', None), ('intent', None), ('of', None), ('its', None), ('authors', None), (',', None), ('as', None), ('well', None), ('as', None), ('the', None), ('views', None), ('of', None), ('previous', None), ('presidents', None), ('.', None)]
# [('A', 'DT'), ('line-item', 'JJ'), ('veto', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('procedure', None), ('that', None), ('would', None), ('allow', None), ('a', None), ('president', None), ('to', None), ('veto', None), ('part', None), ('of', None), ('a', None), ('big', None), ('congressional', None), ('spending', None), ('bill', None), ('without', None), ('having', None), ('to', None), ('scuttle', None), ('the', None), ('entire', None), ('measure', None), ('.', None)]
# [('Mr.', 'NNP'), ('Bush', 'NNP'), ('has', 'VBZ'), ('said', 'VBN'), ('he', None), ('would', None), ('like', None), ('to', None), ('be', None), ('able', None), ('to', None), ('use', None), ('this', None), ('procedure', None), ('.', None)]
# [('A', 'DT'), ('White', 'NNP'), ('House', 'NNP'), ('spokesman', 'NN'), ('said', 'VBD'), ('last', 'JJ'), ('week', 'NN'), ('that', 'WDT'), ('the', 'DT'), ('president', 'NN'), ('is', 'VBZ'), ('considering', 'VBG'), ('declaring', None), ('that', None), ('the', None), ('Constitution', None), ('implicitly', None), ('gives', None), ('him', None), ('the', None), ('authority', None), ('for', None), ('a', None), ('line-item', None), ('veto', None), ('to', None), ('provoke', None), ('a', None), ('test', None), ('case', None), ('.', None)]
# [('But', 'CC'), ('the', 'DT'), ('two', 'CD'), ('legal', None), ('experts', None), (',', None), ('responding', None), ('to', None), ('an', None), ('inquiry', None), ('by', None), ('Sen.', None), ('Edward', None), ('Kennedy', None), ('-LRB-', None), ('D.', None), (',', None), ('Mass.', None), ('-RRB-', None), (',', None), ('wrote', None), ('in', None), ('a', None), ('joint', None), ('letter', None), ('that', None), ('the', None), ('president', None), ('``', None), ('lacks', None), ('the', None), ('constitutional', None), ('authority', None), ('to', None), ('exercise', None), ('a', None), ('line-item', None), ('veto', None), ('.', None)]
# [("''", "''"), ('The', 'DT'), ('two', 'CD'), ('professors', None), ('represent', None), ('different', None), ('ends', None), ('of', None), ('the', None), ('political', None), ('spectrum', None), ('--', None), ('Mr.', None), ('Kurland', None), ('is', None), ('a', None), ('conservative', None), ('and', None), ('Mr.', None), ('Tribe', None), ('is', None), ('a', None), ('liberal', None), ('.', None)]
# [('The', 'DT'), ('two', 'CD'), ('professors', None), ('said', None), ('the', None), ('Constitution', None), ('authorizes', None), ('the', None), ('president', None), ('to', None), ('veto', None), ('entire', None), ('bills', None), (',', None), ('not', None), ('partial', None), ('measures', None), ('.', None)]
# [('Moreover', 'RB'), (',', ','), ('they', 'PRP'), ('said', 'VBD'), ('the', 'DT'), ('first', 'JJ'), ('appropriations', 'NNS'), ('bill', 'NN'), ('passed', 'VBD'), ('200', None), ('years', None), ('ago', None), ('covered', None), ('many', None), ('different', None), ('items', None), (',', None), ('and', None), ('there', None), ('was', None), ('no', None), ('discussion', None), ('of', None), ('a', None), ('line-item', None), ('veto', None), ('.', None)]
# [('They', 'PRP'), ('also', 'RB'), ('said', 'VBD'), ('that', 'IN'), ('more', 'JJR'), ('than', 'IN'), ('a', 'DT'), ('dozen', 'NN'), ('presidents', None), ('have', None), ('called', None), ('for', None), ('line-item', None), ('veto', None), ('authority', None), ('since', None), ('the', None), ('Civil', None), ('War', None), (',', None), ('and', None), ('``', None), ('all', None), ('have', None), ('shared', None), ('the', None), ('view', None), ('that', None), ('such', None), ('lawmaking', None), ('power', None), ('is', None), ('beyond', None), ('the', None), ('reach', None), ("''", None), ('of', None), ('the', None), ('president', None), ('.', None)]
# [('Sen.', 'NNP'), ('Kennedy', None), ('said', None), ('in', None), ('a', None), ('separate', None), ('statement', None), ('that', None), ('he', None), ('supports', None), ('legislation', None), ('to', None), ('give', None), ('the', None), ('president', None), ('line-item', None), ('veto', None), ('power', None), (',', None), ('but', None), ('that', None), ('it', None), ('would', None), ('be', None), ('a', None), ('``', None), ('reckless', None), ('course', None), ('of', None), ('action', None), ("''", None), ('for', None), ('President', None), ('Bush', None), ('to', None), ('claim', None), ('the', None), ('authority', None), ('without', None), ('congressional', None), ('approval', None), ('.', None)]
# Average Precision: 0.125199492165
# Average Recall: 0.944918786624

# %%
t0 = nltk.DefaultTagger('NN')
t1 = nltk.UnigramTagger(training_set, backoff=t0)
t2 = nltk.BigramTagger(training_set, backoff=t1)
t3 = nltk.TrigramTagger(training_set, backoff=t2)
results['Backoff'] = compute_accuracy(t3,'backoff')
# Out:
# Overall Accuracy: 0.882766072393301
# Average Accuracy: 0.8825438245335168
# 1409.0
# Average Precision: 0.848024541932
# Average Recall: 0.886375514646

# %%
hmm_tagger = nltk.HiddenMarkovModelTagger.train(training_set)
results['HMM'] = compute_accuracy(hmm_tagger,'hmm')
# Out:
# Overall Accuracy: 0.8959481361426256
# Average Accuracy: 0.8938869669207187
# 1244.0
# Average Precision: 0.855096551634
# Average Recall: 0.811946588796

# %%
#write results to a file
y_labels = ['Overall Accuracy','Average Accuracy','Average Precision','Average Recall']
table = pd.DataFrame(list(results.values()),columns=y_labels,index=list(results.keys()))
table.to_csv('results.csv', sep='\t')
